# %% [markdown]
# ### Data Preparation:

# %%
#Load the dataset into data frame
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
df =pd.read_csv(r"C:\Users\anura\Desktop\d\heart_disease.csv")
df
# Out:
#      age   sex               cp  trestbps  chol    fbs           restecg  \
# 0     63  Male   typical angina       145   233   True    lv hypertrophy
# 1     41  Male  atypical angina       135   203  False            normal
# 2     57  Male     asymptomatic       140   192  False            normal
# 3     52  Male   typical angina       118   186  False    lv hypertrophy
# 4     57  Male     asymptomatic       110   201  False            normal
# ..   ...   ...              ...       ...   ...    ...               ...
# 903   53  Male     asymptomatic       125     0  False            normal
# 904   62  Male     asymptomatic       166   170  False  st-t abnormality
# 905   56  Male      non-anginal       170     0  False    lv hypertrophy
# 906   56  Male      non-anginal       144   208   True  st-t abnormality
# 907   57  Male     asymptomatic       142   277   True  st-t abnormality
#
#      thalch  exang  oldpeak        slope               thal  num
# ...

# %% [markdown]
# ### Exploratory Data Analysis (EDA):

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 908 entries, 0 to 907
# Data columns (total 13 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       908 non-null    int64
#  1   sex       908 non-null    object
#  2   cp        908 non-null    object
#  3   trestbps  908 non-null    int64
#  4   chol      908 non-null    int64
#  5   fbs       908 non-null    bool
#  6   restecg   908 non-null    object
#  7   thalch    908 non-null    int64
#  8   exang     908 non-null    object
#  9   oldpeak   846 non-null    float64
#  10  slope     908 non-null    object
#  11  thal      908 non-null    object
#  12  num       908 non-null    int64
# dtypes: bool(1), float64(1), int64(5), object(6)
# memory usage: 86.1+ KB

# %%
df.shape
# Out:
# (908, 13)

# %%
#check for missing values

df.isnull().sum()
# Out:
# age          0
# sex          0
# cp           0
# trestbps     0
# chol         0
# fbs          0
# restecg      0
# thalch       0
# exang        0
# oldpeak     62
# slope        0
# thal         0
# num          0
# dtype: int64

# %%
# Fill missing with median/mean
df["oldpeak"].fillna(df["oldpeak"].median(), inplace =True)
# Out:
# C:\Users\anura\AppData\Local\Temp\ipykernel_11968\3048086158.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["oldpeak"].fillna(df["oldpeak"].median(), inplace =True)

# %%
df.isnull().sum()
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalch      0
# exang       0
# oldpeak     0
# slope       0
# thal        0
# num         0
# dtype: int64

# %%
print(df.isnull().sum().sum())
# Out:
# 0

# %% [markdown]
# ### Histograms

# %%
import matplotlib.pyplot as plt 
plt.hist(df["age"])
plt.title("age")
plt.show()

# %%
import matplotlib.pyplot as plt 
plt.hist(df["sex"])
plt.title("sex")
plt.show()

# %%
import matplotlib.pyplot as plt 
plt.hist(df["cp"])
plt.title("cp")
plt.show()

# %%
import matplotlib.pyplot as plt 
plt.hist(df["trestbps"])
plt.title("trestbps")
plt.show()

# %%
import matplotlib.pyplot as plt 
plt.hist(df["chol"])
plt.title("chol")
plt.show()

# %%
import matplotlib.pyplot as plt 
plt.hist(df["restecg"])
plt.title("restecg")
plt.show()

# %%
import matplotlib.pyplot as plt 
plt.hist(df["thalch"])
plt.title("thalch")
plt.show()

# %%
import matplotlib.pyplot as plt 
plt.hist(df["exang"])
plt.title("exang")
plt.show()

# %%
import matplotlib.pyplot as plt 
plt.hist(df["oldpeak"])
plt.title("oldpeak")
plt.show()

# %%
import matplotlib.pyplot as plt 
plt.hist(df["slope"])
plt.title("slope")
plt.show()

# %%
import matplotlib.pyplot as plt 
plt.hist(df["thal"])
plt.title("thal")
plt.show()

# %%
import matplotlib.pyplot as plt 
plt.hist(df["num"])
plt.title("num")
plt.show()

# %% [markdown]
# ### Box plots

# %%
plt.boxplot(df["age"])
plt.title("age")
plt.show()

Q1 =df["age"].quantile(0.25)
Q3 =df["age"].quantile(0.75)

IQR = Q3 - Q1

lower_bound =Q1 -(1.5 * IQR)
upper_bound =Q3 +(1.5 * IQR)

outliers =df[(df["age"] < lower_bound) | (df["age"] > upper_bound)]
print("Outliers in age Columns:", outliers)
# Out:
# Outliers in age Columns:      age   sex               cp  trestbps  chol    fbs         restecg  \
# 134   29  Male  atypical angina       130   204  False  lv hypertrophy
#
#      thalch  exang  oldpeak      slope    thal  num
# 134     202  FALSE      0.0  upsloping  normal    0

# %%
plt.boxplot(df["trestbps"])
plt.title("trestbps")
plt.show()

Q1 =df["trestbps"].quantile(0.25)
Q3 =df["trestbps"].quantile(0.75)

IQR = Q3 - Q1

lower_bound =Q1 -(1.5 * IQR)
upper_bound =Q3 +(1.5 * IQR)

outliers =df[(df["trestbps"] < lower_bound) | (df["trestbps"] > upper_bound)]
print("Outliers in trestbps Columns:", outliers)
print("hilen(outliers))
# Out:
# Outliers in trestbps Columns:      age     sex               cp  trestbps  chol    fbs           restecg  \
# 190   53    Male     asymptomatic        80     0   True            normal
# 243   39    Male  atypical angina       190   241  False            normal
# 383   63  Female  atypical angina       181     0  False            normal
# 384   74    Male      non-anginal       188     0  False            normal
# 387   45    Male      non-anginal       193   236  False            normal
# 396   55    Male      non-anginal       196   406  False  st-t abnormality
# 487   54    Male  atypical angina       192   283  False    lv hypertrophy
# 488   63    Male     asymptomatic       185     0  False            normal
# 589   54    Male     asymptomatic       200   198  False            normal
# 766   69    Male     asymptomatic       184   236   True            normal
# 768   60    Male     asymptomatic       192   281  False  st-t abnormality
# ...

# %%
plt.boxplot(df["chol"])
plt.title("chol")
plt.show()

Q1 =df["chol"].quantile(0.25)
Q3 =df["chol"].quantile(0.75)

IQR = Q3 - Q1

lower_bound =Q1 -(1.5 * IQR)
upper_bound =Q3 +(1.5 * IQR)

outliers =df[(df["chol"] < lower_bound) | (df["chol"] > upper_bound)]
print("Outliers in chol Columns:", outliers)
# Out:
# Outliers in chol Columns:      age     sex            cp  trestbps  chol    fbs           restecg  \
# 74    65  Female   non-anginal       140   417   True    lv hypertrophy
# 147   43  Female   non-anginal       150   439  False            normal
# 152   56    Male   non-anginal       120     0  False            normal
# 157   67  Female   non-anginal       115   564  False    lv hypertrophy
# 176   60    Male  asymptomatic       120     0  False            normal
# ..   ...     ...           ...       ...   ...    ...               ...
# 893   43    Male  asymptomatic       115     0  False            normal
# 895   55    Male  asymptomatic       120     0  False  st-t abnormality
# 901   51    Male  asymptomatic       110     0   True            normal
# 903   53    Male  asymptomatic       125     0  False            normal
# 905   56    Male   non-anginal       170     0  False    lv hypertrophy
#
#      thalch  exang  oldpeak        slope               thal  num
# ...

# %%
plt.boxplot(df["thalch"])
plt.title("thalch")
plt.show()

Q1 =df["thalch"].quantile(0.25)
Q3 =df["thalch"].quantile(0.75)

IQR = Q3 - Q1

lower_bound =Q1 -(1.5 * IQR)
upper_bound =Q3 +(1.5 * IQR)

outliers =df[(df["thalch"] < lower_bound) | (df["thalch"] > upper_bound)]
print("Outliers in thalch Columns:", outliers)
# Out:
# Outliers in thalch Columns:      age   sex            cp  trestbps  chol    fbs restecg  thalch  exang  \
# 676   51  Male  asymptomatic       140     0  False  normal      60  FALSE
#
#      oldpeak slope    thal  num
# 676      0.0  flat  normal    2

# %%
plt.boxplot(df["oldpeak"])
plt.title("oldpeak")
plt.show()

Q1 =df["oldpeak"].quantile(0.25)
Q3 =df["oldpeak"].quantile(0.75)

IQR = Q3 - Q1

lower_bound =Q1 -(1.5 * IQR)
upper_bound =Q3 +(1.5 * IQR)

outliers =df[(df["oldpeak"] < lower_bound) | (df["oldpeak"] > upper_bound)]
print("Outliers in oldpeak Columns:", outliers)
# Out:
# Outliers in oldpeak Columns:      age     sex              cp  trestbps  chol    fbs           restecg  \
# 149   59    Male  typical angina       178   270  False    lv hypertrophy
# 525   46    Male    asymptomatic       100     0  False  st-t abnormality
# 537   52    Male    asymptomatic       160   246  False  st-t abnormality
# 587   50    Male    asymptomatic       140   231  False  st-t abnormality
# 722   63    Male    asymptomatic       140   187  False    lv hypertrophy
# 773   61    Male    asymptomatic       120   282  False  st-t abnormality
# 792   62  Female    asymptomatic       160   164  False    lv hypertrophy
# 794   55    Male    asymptomatic       140   217  False            normal
# 795   56  Female    asymptomatic       200   288   True    lv hypertrophy
# 814   51    Male    asymptomatic       140   298  False            normal
# 839   74    Male    asymptomatic       150   258   True  st-t abnormality
# ...

# %%
plt.boxplot(df["num"])
plt.title("num")
plt.show()

Q1 =df["num"].quantile(0.25)
Q3 =df["num"].quantile(0.75)

IQR = Q3 - Q1

lower_bound =Q1 -(1.5 * IQR)
upper_bound =Q3 +(1.5 * IQR)

outliers =df[(df["num"] < lower_bound) | (df["num"] > upper_bound)]
print("Outliers in num Columns:", outliers)
# Out:
# Outliers in num Columns: Empty DataFrame
# Columns: [age, sex, cp, trestbps, chol, fbs, restecg, thalch, exang, oldpeak, slope, thal, num]
# Index: []

# %%
# (OR)
# Check for outliers using box plots
numeric_cols = df.select_dtypes(include=['int64', 'float64']).columns

print("\nBox plots for numerical columns:")
for col in numeric_cols:
    plt.figure(figsize=(6, 1.5))
    sns.boxplot(data=df, x=col)
    plt.title(f'Box plot for {col}')
    plt.show()
# Out:
# Box plots for numerical columns:

# %%
numerical_col =df.select_dtypes(include =['int64', 'float64']).columns
numerical_col
# Out:
# Index(['age', 'trestbps', 'chol', 'thalch', 'oldpeak', 'num'], dtype='object')

# %%
numerical_cols = df.select_dtypes(include=['number'])
numerical_cols
# Out:
#      age  trestbps  chol  thalch  oldpeak  num
# 0     63       145   233     150      2.3    0
# 1     41       135   203     132      0.0    0
# 2     57       140   192     148      0.4    0
# 3     52       118   186     190      0.0    0
# 4     57       110   201     126      1.5    0
# ..   ...       ...   ...     ...      ...  ...
# 903   53       125     0     120      1.5    4
# 904   62       166   170     120      3.0    4
# 905   56       170     0     123      2.5    4
# 906   56       144   208     105      0.5    4
# 907   57       142   277     182      0.5    4
#
# [908 rows x 6 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sns

numerical_cols = df.select_dtypes(include=['number'])
correlation_matric =numerical_cols.corr()
print(correlation_matric)

plt.figure(figsize =(6, 4))
sns.heatmap(correlation_matric, annot =True, cmap ='coolwarm', fmt =".2f")
plt.title("'Correlation Matrix of Numerical Features'")
plt.show()
# Out:
#                age  trestbps      chol    thalch   oldpeak       num
# age       1.000000  0.253999 -0.099967 -0.328088  0.217942  0.326493
# trestbps  0.253999  1.000000  0.117488 -0.133360  0.134945  0.137251
# chol     -0.099967  0.117488  1.000000  0.197907  0.032205 -0.238813
# thalch   -0.328088 -0.133360  0.197907  1.000000 -0.112624 -0.323058
# oldpeak   0.217942  0.134945  0.032205 -0.112624  1.000000  0.406078
# num       0.326493  0.137251 -0.238813 -0.323058  0.406078  1.000000

# %% [markdown]
# ### 3. Feature Engineering:

# %%
#categorical variables

categorical_col =df.select_dtypes(include =["object"]).columns
categorical_col
# Out:
# Index(['sex', 'cp', 'restecg', 'exang', 'slope', 'thal'], dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 908 entries, 0 to 907
# Data columns (total 13 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       908 non-null    int64
#  1   sex       908 non-null    object
#  2   cp        908 non-null    object
#  3   trestbps  908 non-null    int64
#  4   chol      908 non-null    int64
#  5   fbs       908 non-null    bool
#  6   restecg   908 non-null    object
#  7   thalch    908 non-null    int64
#  8   exang     908 non-null    object
#  9   oldpeak   908 non-null    float64
#  10  slope     908 non-null    object
#  11  thal      908 non-null    object
#  12  num       908 non-null    int64
# dtypes: bool(1), float64(1), int64(5), object(6)
# memory usage: 86.1+ KB

# %%
X_count =df[df.columns[[0,3,4,7,9,12]]]

# %%
#2.scaling /normalization -->It will also remove the units and adjust data in bln [0 to 1]
from sklearn.preprocessing import MinMaxScaler 
MM =MinMaxScaler()
MM_X =MM.fit_transform(X_count)
MM_X =pd.DataFrame(MM_X)
MM_X.columns =list(df.columns[[0,3,4,7,9,12]])
MM_X
# Out:
#           age  trestbps      chol    thalch   oldpeak  num
# 0    0.708333     0.725  0.386401  0.633803  0.556818  0.0
# 1    0.250000     0.675  0.336650  0.507042  0.295455  0.0
# 2    0.583333     0.700  0.318408  0.619718  0.340909  0.0
# 3    0.479167     0.590  0.308458  0.915493  0.295455  0.0
# 4    0.583333     0.550  0.333333  0.464789  0.465909  0.0
# ..        ...       ...       ...       ...       ...  ...
# 903  0.500000     0.625  0.000000  0.422535  0.465909  1.0
# 904  0.687500     0.830  0.281924  0.422535  0.636364  1.0
# 905  0.562500     0.850  0.000000  0.443662  0.579545  1.0
# 906  0.562500     0.720  0.344942  0.316901  0.352273  1.0
# 907  0.583333     0.710  0.459370  0.859155  0.352273  1.0
#
# [908 rows x 6 columns]

# %%
#encoding categorical variables
from sklearn.preprocessing import LabelEncoder
LE=LabelEncoder()
df["sex"]      =LE.fit_transform(df["sex"])
print(df["sex"])
df["cp"]       =LE.fit_transform(df["cp"])
print(df["cp"])
df["restecg"]  =LE.fit_transform(df["restecg"])
print(df["restecg"])
df["fbs"]       =LE.fit_transform(df["fbs"])
print(df["fbs"])
df["exang"]     =LE.fit_transform(df["exang"])
print(df["exang"])
df["slope"]    =LE.fit_transform(df["slope"])
print(df["slope"])
df["thal"]     =LE.fit_transform(df["thal"])
print(df["thal"])

df.head()
# Out:
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 903    1
# 904    1
# 905    1
# 906    1
# 907    1
# Name: sex, Length: 908, dtype: int32
# 0      3
# 1      1
# 2      0
# 3      3
# 4      0
#       ..
# 903    0
# 904    0
# 905    2
# 906    2
# 907    0
# Name: cp, Length: 908, dtype: int32
# 0      0
# 1      1
# 2      1
# 3      0
# 4      1
#       ..
# 903    1
# 904    2
# 905    0
# 906    2
# 907    2
# Name: restecg, Length: 908, dtype: int32
# 0      1
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 903    0
# 904    0
# 905    0
# 906    1
# 907    1
# Name: fbs, Length: 908, dtype: int64
# 0      0
# 1      0
# 2      0
# 3      0
# 4      1
#       ..
# 903    0
# 904    1
# 905    1
# 906    2
# 907    0
# Name: exang, Length: 908, dtype: int32
# 0      0
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 903    2
# 904    1
# 905    0
# 906    0
# 907    1
# Name: slope, Length: 908, dtype: int32
# 0      0
# 1      0
# 2      0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 908 entries, 0 to 907
# Data columns (total 13 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       908 non-null    int64
#  1   sex       908 non-null    int32
#  2   cp        908 non-null    int32
#  3   trestbps  908 non-null    int64
#  4   chol      908 non-null    int64
#  5   fbs       908 non-null    int64
#  6   restecg   908 non-null    int32
#  7   thalch    908 non-null    int64
#  8   exang     908 non-null    int32
#  9   oldpeak   908 non-null    float64
#  10  slope     908 non-null    int32
#  11  thal      908 non-null    int32
#  12  num       908 non-null    int64
# dtypes: float64(1), int32(6), int64(6)
# memory usage: 71.1 KB

# %%
df_cat =df[df.columns[[1,2,5,6,8,10,11]]]

# %%
df_new =pd.concat([MM_X, df_cat], axis =1)
df_new
# Out:
#           age  trestbps      chol    thalch   oldpeak  num  sex  cp  fbs  \
# 0    0.708333     0.725  0.386401  0.633803  0.556818  0.0    1   3    1
# 1    0.250000     0.675  0.336650  0.507042  0.295455  0.0    1   1    0
# 2    0.583333     0.700  0.318408  0.619718  0.340909  0.0    1   0    0
# 3    0.479167     0.590  0.308458  0.915493  0.295455  0.0    1   3    0
# 4    0.583333     0.550  0.333333  0.464789  0.465909  0.0    1   0    0
# ..        ...       ...       ...       ...       ...  ...  ...  ..  ...
# 903  0.500000     0.625  0.000000  0.422535  0.465909  1.0    1   0    0
# 904  0.687500     0.830  0.281924  0.422535  0.636364  1.0    1   0    0
# 905  0.562500     0.850  0.000000  0.443662  0.579545  1.0    1   2    0
# 906  0.562500     0.720  0.344942  0.316901  0.352273  1.0    1   2    1
# 907  0.583333     0.710  0.459370  0.859155  0.352273  1.0    1   0    1
#
#      restecg  exang  slope  thal
# 0          0      0      0     0
# ...

# %%
df_new['num'] = df_new['num'].astype(int)
df_new['num']
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 903    1
# 904    1
# 905    1
# 906    1
# 907    1
# Name: num, Length: 908, dtype: int32

# %%
#Data partition 

Y =df_new['num']
X =df_new.drop(df_new[['num']], axis =1)
X
# Out:
#           age  trestbps      chol    thalch   oldpeak  sex  cp  fbs  restecg  \
# 0    0.708333     0.725  0.386401  0.633803  0.556818    1   3    1        0
# 1    0.250000     0.675  0.336650  0.507042  0.295455    1   1    0        1
# 2    0.583333     0.700  0.318408  0.619718  0.340909    1   0    0        1
# 3    0.479167     0.590  0.308458  0.915493  0.295455    1   3    0        0
# 4    0.583333     0.550  0.333333  0.464789  0.465909    1   0    0        1
# ..        ...       ...       ...       ...       ...  ...  ..  ...      ...
# 903  0.500000     0.625  0.000000  0.422535  0.465909    1   0    0        1
# 904  0.687500     0.830  0.281924  0.422535  0.636364    1   0    0        2
# 905  0.562500     0.850  0.000000  0.443662  0.579545    1   2    0        0
# 906  0.562500     0.720  0.344942  0.316901  0.352273    1   2    1        2
# 907  0.583333     0.710  0.459370  0.859155  0.352273    1   0    1        2
#
#      exang  slope  thal
# ...

# %%
df['num'].value_counts()
# Out:
# num
# 0    399
# 1    265
# 2    109
# 3    107
# 4     28
# Name: count, dtype: int64

# %% [markdown]
# ### 4. Decision Tree Classification:

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test =train_test_split(X,Y, test_size =0.2) #random_state=42, stratify=Y

# %%
X.head()
# Out:
#         age  trestbps      chol    thalch   oldpeak  sex  cp  fbs  restecg  \
# 0  0.708333     0.725  0.386401  0.633803  0.556818    1   3    1        0
# 1  0.250000     0.675  0.336650  0.507042  0.295455    1   1    0        1
# 2  0.583333     0.700  0.318408  0.619718  0.340909    1   0    0        1
# 3  0.479167     0.590  0.308458  0.915493  0.295455    1   3    0        0
# 4  0.583333     0.550  0.333333  0.464789  0.465909    1   0    0        1
#
#    exang  slope  thal
# 0      0      0     0
# 1      0      1     0
# 2      0      1     0
# 3      0      1     0
# 4      1      1     0

# %%
Y.head()
# Out:
# 0    0
# 1    0
# 2    0
# 3    0
# 4    0
# Name: num, dtype: int32

# %%
from sklearn.tree import DecisionTreeClassifier
model =DecisionTreeClassifier()
model.fit(X_train, Y_train)

y_pred_train =model.predict(X_train)
y_pred_test  =model.predict(X_test)

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score,log_loss
 
training_accuracy =accuracy_score(Y_train, y_pred_train)
test_accuracy     =accuracy_score(Y_test, y_pred_test)
precision         =precision_score(Y_test, y_pred_test)  
recall            =recall_score(Y_test, y_pred_test)
f1score           =f1_score(Y_test, y_pred_test)


print("training accuracy:", np.round(training_accuracy, 2))
print("test accuracy:",     np.round(test_accuracy, 2))
print("Decision Tree - precision score - Test Accuracy:", precision)
print("Decision Tree - recall score    - Test Accuracy:", recall)
print("Decision Tree - f1 score        -  Test Accuracy:", f1score)
# Out:
# training accuracy: 1.0
# test accuracy: 0.93
# Decision Tree - precision score - Test Accuracy: 0.375
# Decision Tree - recall score    - Test Accuracy: 0.3
# Decision Tree - f1 score        -  Test Accuracy: 0.3333333333333333

# %%
from sklearn.metrics import roc_curve, roc_auc_score 

fpr,tpr,dummy =roc_curve(Y_train, y_pred_train)

import matplotlib.pyplot as plt 
plt.scatter(x =fpr, y =tpr)
plt.plot(fpr,tpr, color ="red")
plt.ylabel("True Positive Rate")
plt.xlabel("False Positive Rate")
plt.show()

# %%
auc =roc_auc_score(Y_test, y_pred_test)
print("Area under curve:", (auc * 100).round(3))
# Out:
# Area under curve: 63.547

# %%
#shuffle split
training_accuracy =[]
test_accuracy     =[]
precision         =[]
recall            =[]
f1score           =[]

for i in range(1, 501):
    X_train,X_test,Y_train,Y_test =train_test_split(X,Y, test_size =0.2, random_state =i)
    model =DecisionTreeClassifier(criterion ='gini')
    model.fit(X_train, Y_train)
    y_pred_train =model.predict(X_train)
    y_pre_test   =model.predict(X_test)
    training_accuracy.append(accuracy_score(Y_train, y_pred_train))
    test_accuracy.append(accuracy_score(Y_test, y_pred_test))
    precision.append(precision_score(Y_test, y_pred_test))
    recall.append(recall_score(Y_train, y_pred_train))
    f1score.append(f1_score(Y_test, y_pred_test))

print("Cross validation: Training accuracy scoe:", np.round(np.mean(training_accuracy), 2))
print("Cross validation: Test accuracy score:",    np.round(np.mean(test_accuracy), 2))
print("Cross Validation : Test Precision:",        np.round(np.mean(precision), 2))
print("Cross validation: Test recall:",            np.round(np.mean(recall), 2))
print("Cross validation: Test f1score:",           np.round(np.mean(f1score), 2))
# Out:
# Cross validation: Training accuracy scoe: 1.0
# Cross validation: Test accuracy score: 0.93
# Cross Validation : Test Precision: 0.03
# Cross validation: Test recall: 1.0
# Cross validation: Test f1score: 0.03

# %% [markdown]
# ### 5. Hyperparameter Tuning:

# %%
import xgboost as xgb

# XGBoost Classifier
xgb_model = xgb.XGBClassifier(n_estimators = 100,Learning_rate=0.1,gamma=100,reg_lambda = 10)
xgb_model.fit(X_train, Y_train)

y_pred_train_xgb = xgb_model.predict(X_train)
y_pred_test_xgb = xgb_model.predict(X_test)

training_accuracy_xgb = accuracy_score(Y_train, y_pred_train_xgb)
test_accuracy_xgb = accuracy_score(Y_test, y_pred_test_xgb)
training_loss_xgb = log_loss(Y_train, y_pred_train_xgb)
test_loss_xgb = log_loss(Y_test, y_pred_test_xgb)

print("XGBoost - Training Accuracy:", training_accuracy_xgb)
print("XGBoost - Test Accuracy:", test_accuracy_xgb)
print("XGBoost - Training Loss:", training_loss_xgb)
print("XGBoost - Test Loss:", test_loss_xgb)
# Out:
# XGBoost - Training Accuracy: 0.9683195592286501
# XGBoost - Test Accuracy: 0.9725274725274725
# XGBoost - Training Loss: 1.14187882637699
# XGBoost - Test Loss: 0.9902102579427792
# C:\Users\anura\anaconda5-3-25\Lib\site-packages\xgboost\training.py:183: UserWarning: [22:28:43] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:738:
# Parameters: { "Learning_rate" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)

# %%
from sklearn.model_selection import GridSearchCV

# Define the parameter grid
param_grid = {
    'n_estimators': [100, 200, 300],
    'learning_rate': [0.1, 1, 0.01],
    'gamma': [10, 20, 50],
    'reg_lambda': [1, 5, 10]
}

# Create the XGBoost classifier
xgb_model = xgb.XGBClassifier()

# Create the GridSearchCV object
grid_search = GridSearchCV(estimator=xgb_model, param_grid=param_grid, cv=5, scoring='accuracy') # You can change scoring as needed

# Fit the grid search to the data
grid_search.fit(X_train, Y_train)

# Get the best parameters and best score
best_params = grid_search.best_params_
best_score = grid_search.best_score_

print(f"Best parameters: {best_params}")
print(f"Best score: {best_score}")

# Evaluate the best model on the test set
best_model = grid_search.best_estimator_
y_pred_test = best_model.predict(X_test)
test_accuracy = accuracy_score(Y_test, y_pred_test)
print(f"Test accuracy of the best model: {test_accuracy}")
# Out:
# Best parameters: {'gamma': 10, 'learning_rate': 0.1, 'n_estimators': 100, 'reg_lambda': 1}
# Best score: 0.9683230987246103
# Test accuracy of the best model: 0.9725274725274725

# %% [markdown]
# ### 6. Model Evaluation and Analysis:

# %%
from sklearn.tree import plot_tree
import matplotlib.pyplot as plt

plt.figure(figsize =(20, 10))
plot_tree(model, filled =True, feature_names =X.columns, class_names =['Low', 'High'], rounded =True)
plt.show()

# %%
from sklearn.tree import DecisionTreeClassifier 

n_nodes =model.tree_.node_count
depth   =model.tree_.max_depth

print(f"Number of nodes: {n_nodes}")
print(f"Depth of tree: {depth}")
# Out:
# Number of nodes: 67
# Depth of tree: 9

# %%
from sklearn.ensemble import BaggingClassifier

# Bagging Classifier
bagging_model = BaggingClassifier(estimator=DecisionTreeClassifier(criterion='gini'),
                                  n_estimators=100, random_state=42,
                                  max_samples=0.6,max_features=0.7)
bagging_model.fit(X_train, Y_train)

y_pred_train_bagging = bagging_model.predict(X_train)
y_pred_test_bagging = bagging_model.predict(X_test)

training_accuracy_bagging = accuracy_score(Y_train, y_pred_train_bagging)
test_accuracy_bagging = accuracy_score(Y_test, y_pred_test_bagging)
training_loss_bagging = log_loss(Y_train, y_pred_train_bagging)
test_loss_bagging = log_loss(Y_test, y_pred_test_bagging)

print("Bagging - Training Accuracy:", training_accuracy_bagging)
print("Bagging - Test Accuracy:", test_accuracy_bagging)
print("Bagging - Training Loss:", training_loss_bagging)
print("Bagging - Test Loss:", test_loss_bagging)
# Out:
# Bagging - Training Accuracy: 0.9834710743801653
# Bagging - Test Accuracy: 0.9725274725274725
# Bagging - Training Loss: 0.5957628659358208
# Bagging - Test Loss: 0.9902102579427792

# %%
#Key Metrics:
print('''Accuracy: Cross validation: Training accuracy scoe: 1.0
             Cross validation: Test accuracy score: 0.93
Precision:Cross Validation : Test Precision: 0.03
Recall: Cross validation: Test recall: 1.0
F1-score: Cross validation: Test f1score: 0.02''')
# Out:
# Accuracy: Cross validation: Training accuracy scoe: 1.0
#              Cross validation: Test accuracy score: 0.93
# Precision:Cross Validation : Test Precision: 0.03
# Recall: Cross validation: Test recall: 1.0
# F1-score: Cross validation: Test f1score: 0.02

# %% [markdown]
# ## Interview Questions:

# %%
#1. What are some common hyperparameters of decision tree models, and how do they affect the model's performance?
#Decision tree models (like those in scikit-learn or XGBoost) have several hyperparameters that control their complexity, accuracy, and generalization. Here's a summary of the most important ones:
print('''
1. max_depth
    What it does: Limits the maximum depth of the tree.

    Effect:

        Low value → underfitting (tree too shallow).

        High value → overfitting (tree too deep).
2. min_samples_split
    What it does: Minimum number of samples required to split an internal node.

    Effect:

        Higher value → more conservative splits → less overfitting.

        Lower value → more splits → risk of overfitting.
3. min_samples_leaf
    What it does: Minimum number of samples required to be at a leaf node.

    Effect:

        Helps smooth the model by requiring larger leaf nodes.

        Higher value → more generalization, less overfitting.
4. max_features
    What it does: Number of features to consider when looking for the best split.

    Effect:

        Smaller value introduces randomness → helps in ensemble methods (like Random Forest).

        Larger value → more accurate splits, but risk of overfitting.

5. max_leaf_nodes
    What it does: Limits the number of leaf nodes.

    Effect:

        Controls model complexity.

        Prevents overfitting by stopping further growth once the limit is reached.

6. criterion
    What it does: The function used to measure the quality of a split.

    gini: Gini impurity (default).

    entropy: Information gain.

    Effect:

        Slight differences in performance; gini is faster, entropy may be more informative.

7. splitter
    What it does: Strategy used to choose the split at each node (best or random).

    Effect:

        best: Finds optimal split (can overfit).

        random: Adds randomness (useful in ensemble settings).
''')
# Out:
# 1. max_depth
#     What it does: Limits the maximum depth of the tree.
#
#     Effect:
#
#         Low value → underfitting (tree too shallow).
#
#         High value → overfitting (tree too deep).
# 2. min_samples_split
#     What it does: Minimum number of samples required to split an internal node.
#
#     Effect:
#
#         Higher value → more conservative splits → less overfitting.
#
#         Lower value → more splits → risk of overfitting.
# 3. min_samples_leaf
#     What it does: Minimum number of samples required to be at a leaf node.
#
#     Effect:
#
#         Helps smooth the model by requiring larger leaf nodes.
#
#         Higher value → more generalization, less overfitting.
# 4. max_features
#     What it does: Number of features to consider when looking for the best split.
#
#     Effect:
#
#         Smaller value introduces randomness → helps in ensemble methods (like Random Forest).
#
#         Larger value → more accurate splits, but risk of overfitting.
#
# ...

# %%
#2. What is the difference between the Label encoding and One-hot encoding?
print('''
1. Label Encoding
How it works: Converts each category into a unique integer value.
2. One-Hot Encoding
How it works:
---->Creates a binary column for each category.
---->Each observation is marked with 1 in the column of its category, and 0 elsewhere.
| Feature                  | Label Encoding              | One-Hot Encoding               |
| ------------------------ | --------------------------- | ------------------------------ |
| Output Format            | Integer labels (0, 1, 2, …) | Binary vectors (0/1 per class) |
| Suitable For             | Ordinal data                | Nominal data                   |
| Memory Efficient         | Yes                         | No (high-dimensional output)   |
| Risk of Misleading Order | Yes                         | No                             |
''')
# Out:
# 1. Label Encoding
# How it works: Converts each category into a unique integer value.
# 2. One-Hot Encoding
# How it works:
# ---->Creates a binary column for each category.
# ---->Each observation is marked with 1 in the column of its category, and 0 elsewhere.
# | Feature                  | Label Encoding              | One-Hot Encoding               |
# | ------------------------ | --------------------------- | ------------------------------ |
# | Output Format            | Integer labels (0, 1, 2, …) | Binary vectors (0/1 per class) |
# | Suitable For             | Ordinal data                | Nominal data                   |
# | Memory Efficient         | Yes                         | No (high-dimensional output)   |
# | Risk of Misleading Order | Yes                         | No                             |
