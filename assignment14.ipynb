# %%
#Load the dataset into data frame
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
df =pd.read_csv(r"C:\Users\anura\Desktop\glass.csv")
df
# Out:
#           RI     Na    Mg    Al     Si     K    Ca   Ba   Fe  Type
# 0    1.52101  13.64  4.49  1.10  71.78  0.06  8.75  0.0  0.0   1.0
# 1    1.51761  13.89  3.60  1.36  72.73  0.48  7.83  0.0  0.0   1.0
# 2    1.51618  13.53  3.55  1.54  72.99  0.39  7.78  0.0  0.0   1.0
# 3    1.51766  13.21  3.69  1.29  72.61  0.57  8.22  0.0  0.0   1.0
# 4    1.51742  13.27  3.62  1.24  73.08  0.55  8.07  0.0  0.0   1.0
# ..       ...    ...   ...   ...    ...   ...   ...  ...  ...   ...
# 994      NaN    NaN   NaN   NaN    NaN   NaN   NaN  NaN  NaN   NaN
# 995      NaN    NaN   NaN   NaN    NaN   NaN   NaN  NaN  NaN   NaN
# 996      NaN    NaN   NaN   NaN    NaN   NaN   NaN  NaN  NaN   NaN
# 997      NaN    NaN   NaN   NaN    NaN   NaN   NaN  NaN  NaN   NaN
# 998      NaN    NaN   NaN   NaN    NaN   NaN   NaN  NaN  NaN   NaN
#
# [999 rows x 10 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 999 entries, 0 to 998
# Data columns (total 10 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   RI      214 non-null    float64
#  1   Na      214 non-null    float64
#  2   Mg      214 non-null    float64
#  3   Al      214 non-null    float64
#  4   Si      214 non-null    float64
#  5   K       214 non-null    float64
#  6   Ca      214 non-null    float64
#  7   Ba      214 non-null    float64
#  8   Fe      214 non-null    float64
#  9   Type    214 non-null    float64
# dtypes: float64(10)
# memory usage: 78.2 KB

# %%
df.shape
# Out:
# (999, 10)

# %% [markdown]
# ### 1. Exploratory Data Analysis (EDA):

# %%
#missing values

df.isnull().sum()
# Out:
# RI      785
# Na      785
# Mg      785
# Al      785
# Si      785
# K       785
# Ca      785
# Ba      785
# Fe      785
# Type    785
# dtype: int64

# %%
#remove the null values

df.dropna(how='all', inplace=True)

# %%
#After removeing null values

df.isnull().sum()
# Out:
# RI      0
# Na      0
# Mg      0
# Al      0
# Si      0
# K       0
# Ca      0
# Ba      0
# Fe      0
# Type    0
# dtype: int64

# %%
#Detect and treat outliers using IQR
Q1 = df.quantile(0.25)
Q3 = df.quantile(0.75)
IQR = Q3 - Q1

# Boolean mask for outliers
outliers = (df < (Q1 - 1.5 * IQR)) | (df > (Q3 + 1.5 * IQR))

# Count of outliers per column
print(outliers.sum())
# Out:
# RI      17
# Na       7
# Mg       0
# Al      18
# Si      12
# K        7
# Ca      26
# Ba      38
# Fe      12
# Type    29
# dtype: int64

# %% [markdown]
# ### 2: Data Visualization:

# %% [markdown]
# ###  Histograms

# %%
import matplotlib.pyplot as plt
plt.hist(df["RI"])
plt.title("refractive index")
plt.show()

# %%
import matplotlib.pyplot as plt
plt.hist(df["Na"])
plt.title("Sodium")
plt.show()

# %%
import matplotlib.pyplot as plt
plt.hist(df["Mg"])
plt.title("Magnesium")
plt.show()

# %%
import matplotlib.pyplot as plt
plt.hist(df["Al"])
plt.title("Aluminum")
plt.show()

# %%
import matplotlib.pyplot as plt
plt.hist(df["Si"])
plt.title("Silicon")
plt.show()

# %%
import matplotlib.pyplot as plt
plt.hist(df["K"])
plt.title("Potassium")
plt.show()

# %%
import matplotlib.pyplot as plt
plt.hist(df["Ca"])
plt.title(" Calcium")
plt.show()

# %%
import matplotlib.pyplot as plt
plt.hist(df["Ba"])
plt.title("Barium")
plt.show()

# %%
import matplotlib.pyplot as plt
plt.hist(df["Fe"])
plt.title("Iron")
plt.show()

# %%
import matplotlib.pyplot as plt
plt.hist(df["Type"])
plt.title(" Type of glass")
plt.show()

# %% [markdown]
# ### Box plots

# %%
plt.boxplot(df["RI"])
plt.title("refractive index")
plt.show()

# %%
plt.boxplot(df["Na"])
plt.title("Sodium")
plt.show()

# %%
plt.boxplot(df["Mg"])
plt.title("Magnesium")
plt.show()

# %%
plt.boxplot(df["Al"])
plt.show()

# %%
plt.boxplot(df["Si"])
plt.title("Silicon")
plt.show()

# %%
plt.boxplot(df["K"])
plt.title("Potassium")
plt.show()

# %%
plt.boxplot(df["Ca"])
plt.title(" Calcium")
plt.show()

# %%
plt.boxplot(df["Ba"])
plt.title("Barium")
plt.show()

# %%
plt.boxplot(df["Fe"])
plt.title("Iron")
plt.show()

# %%
plt.boxplot(df["Type"])
plt.title(" Type of glass")
plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Load your dataset
#df = pd.read_csv("glass.csv")  
#df.dropna(how='all', inplace=True)  # Remove completely empty rows

# Create the pair plot
sns.pairplot(df, hue='Type', diag_kind='kde', corner=True, palette='tab10')
plt.suptitle("Pair Plot of Glass Dataset Features", y=1.02)
plt.show()

# %%
#correlations observed in the data.

df.corr()
# Out:
#             RI        Na        Mg        Al        Si         K        Ca  \
# RI    1.000000 -0.191885 -0.122274 -0.407326 -0.542052 -0.289833  0.810403
# Na   -0.191885  1.000000 -0.273732  0.156794 -0.069809 -0.266087 -0.275442
# Mg   -0.122274 -0.273732  1.000000 -0.481799 -0.165927  0.005396 -0.443750
# Al   -0.407326  0.156794 -0.481799  1.000000 -0.005524  0.325958 -0.259592
# Si   -0.542052 -0.069809 -0.165927 -0.005524  1.000000 -0.193331 -0.208732
# K    -0.289833 -0.266087  0.005396  0.325958 -0.193331  1.000000 -0.317836
# Ca    0.810403 -0.275442 -0.443750 -0.259592 -0.208732 -0.317836  1.000000
# Ba   -0.000386  0.326603 -0.492262  0.479404 -0.102151 -0.042618 -0.112841
# Fe    0.143010 -0.241346  0.083060 -0.074402 -0.094201 -0.007719  0.124968
# Type -0.164237  0.502898 -0.744993  0.598829  0.151565 -0.010054  0.000952
#
#             Ba        Fe      Type
# RI   -0.000386  0.143010 -0.164237
# Na    0.326603 -0.241346  0.502898
# Mg   -0.492262  0.083060 -0.744993
# ...

# %% [markdown]
# ### 3: Data Preprocessing

# %%
#Dropped fully empty rows	Useless for analysis
#Imputed numerical NaNs with mean	Maintains dataset size and is statistically neutral for small gaps

# %%
#categorical variables
categorical_col =df.select_dtypes("object").columns
categorical_col
# Out:
# Index([], dtype='object')

# %%
'''All these columns:

Are numerical features (float values)

The Type column is already numeric (e.g., 1.0, 2.0... etc.), used as the target variable

There are no categorical columns (like strings or object types) that need encoding. '''
# Out:
# 'All these columns:\n\nAre numerical features (float values)\n\nThe Type column is already numeric (e.g., 1.0, 2.0... etc.), used as the target variable\n\nThere are no categorical columns (like strings or object types) that need encoding. '

# %%
X_count =df.iloc[:, 0:9]
X_count
# Out:
#           RI     Na    Mg    Al     Si     K    Ca    Ba   Fe
# 0    1.52101  13.64  4.49  1.10  71.78  0.06  8.75  0.00  0.0
# 1    1.51761  13.89  3.60  1.36  72.73  0.48  7.83  0.00  0.0
# 2    1.51618  13.53  3.55  1.54  72.99  0.39  7.78  0.00  0.0
# 3    1.51766  13.21  3.69  1.29  72.61  0.57  8.22  0.00  0.0
# 4    1.51742  13.27  3.62  1.24  73.08  0.55  8.07  0.00  0.0
# ..       ...    ...   ...   ...    ...   ...   ...   ...  ...
# 209  1.51623  14.14  0.00  2.88  72.61  0.08  9.18  1.06  0.0
# 210  1.51685  14.92  0.00  1.99  73.06  0.00  8.40  1.59  0.0
# 211  1.52065  14.36  0.00  2.02  73.42  0.00  8.44  1.64  0.0
# 212  1.51651  14.38  0.00  1.94  73.61  0.00  8.48  1.57  0.0
# 213  1.51711  14.23  0.00  2.08  73.36  0.00  8.62  1.67  0.0
#
# [214 rows x 9 columns]

# %%
#Apply feature scaling techniques such as standardization or normalization

#Data transformation 
#1.standardization --->Remove the units from the data between [-3 to +3 ]only
from sklearn.preprocessing import StandardScaler
SS =StandardScaler()
SS_X =SS.fit_transform(X_count)
SS_X =pd.DataFrame(SS_X)
SS_X.columns =list(X_count)
SS_X
# Out:
#            RI        Na        Mg        Al        Si         K        Ca  \
# 0    0.872868  0.284953  1.254639 -0.692442 -1.127082 -0.671705 -0.145766
# 1   -0.249333  0.591817  0.636168 -0.170460  0.102319 -0.026213 -0.793734
# 2   -0.721318  0.149933  0.601422  0.190912  0.438787 -0.164533 -0.828949
# 3   -0.232831 -0.242853  0.698710 -0.310994 -0.052974  0.112107 -0.519052
# 4   -0.312045 -0.169205  0.650066 -0.411375  0.555256  0.081369 -0.624699
# ..        ...       ...       ...       ...       ...       ...       ...
# 209 -0.704815  0.898681 -1.865511  2.881125 -0.052974 -0.640968  0.157088
# 210 -0.500178  1.856097 -1.865511  1.094342  0.529374 -0.763919 -0.392276
# 211  0.754046  1.168721 -1.865511  1.154570  0.995252 -0.763919 -0.364103
# 212 -0.612399  1.193270 -1.865511  0.993960  1.241133 -0.763919 -0.335931
# 213 -0.414363  1.009152 -1.865511  1.275028  0.917606 -0.763919 -0.237327
#
#            Ba        Fe
# 0   -0.352877 -0.586451
# 1   -0.352877 -0.586451
# ...

# %%
#Data partition 

Y =df['Type']
X =df.drop(df[['Type']], axis =1)
X
# Out:
#           RI     Na    Mg    Al     Si     K    Ca    Ba   Fe
# 0    1.52101  13.64  4.49  1.10  71.78  0.06  8.75  0.00  0.0
# 1    1.51761  13.89  3.60  1.36  72.73  0.48  7.83  0.00  0.0
# 2    1.51618  13.53  3.55  1.54  72.99  0.39  7.78  0.00  0.0
# 3    1.51766  13.21  3.69  1.29  72.61  0.57  8.22  0.00  0.0
# 4    1.51742  13.27  3.62  1.24  73.08  0.55  8.07  0.00  0.0
# ..       ...    ...   ...   ...    ...   ...   ...   ...  ...
# 209  1.51623  14.14  0.00  2.88  72.61  0.08  9.18  1.06  0.0
# 210  1.51685  14.92  0.00  1.99  73.06  0.00  8.40  1.59  0.0
# 211  1.52065  14.36  0.00  2.02  73.42  0.00  8.44  1.64  0.0
# 212  1.51651  14.38  0.00  1.94  73.61  0.00  8.48  1.57  0.0
# 213  1.51711  14.23  0.00  2.08  73.36  0.00  8.62  1.67  0.0
#
# [214 rows x 9 columns]

# %% [markdown]
# ### 4: Random Forest Model Implementation

# %%
#Divide the data into train and test split.

from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test =train_test_split(X,Y, test_size =0.2, random_state =100, stratify=Y)

# %%
#Implement a Random Forest classifier using Python and a machine learning library like scikit-learn.

from sklearn.ensemble import RandomForestClassifier

# Random Forest Classifier
rf_model = RandomForestClassifier(n_estimators=100, random_state=42,
                                  max_samples=0.6, max_features=0.7,max_depth=10)
rf_model.fit(X_train, Y_train)

y_pred_train_rf = rf_model.predict(X_train)
y_pred_test_rf = rf_model.predict(X_test)

# %%
# Train the model on the train dataset. Evaluate the performance on test data using metrics like accuracy, precision, recall, and F1-score.

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score,log_loss

#training_accuracy_rf = accuracy_score(Y_train, y_pred_train_rf)
test_accuracy_rf = accuracy_score(Y_test, y_pred_test_rf)


#print("Random Forest - Training Accuracy:", training_accuracy_rf)
print("Random Forest - Test Accuracy:", test_accuracy_rf)
# Out:
# Random Forest - Test Accuracy: 0.7906976744186046

# %%
from sklearn.metrics import precision_score

#precision = precision_score(Y_train, y_pred_train_rf , pos_label='positive', average='micro')
precision =precision_score(Y_test, y_pred_test_rf,  pos_label='positive', average='micro')


#print("Random Forest -precision score - Training Accuracy:", precision)
print("Random Forest -precision score - Test Accuracy:", precision)
# Out:
# Random Forest -precision score - Test Accuracy: 0.7906976744186046
# C:\Users\anura\anaconda5-3-25\Lib\site-packages\sklearn\metrics\_classification.py:1583: UserWarning: Note that pos_label (set to 'positive') is ignored when average != 'binary' (got 'micro'). You may use labels=[pos_label] to specify a single positive class.
#   warnings.warn(

# %%
#recall = precision_score(Y_train, y_pred_train_rf , pos_label='positive', average='micro')
recall  =recall_score(Y_test, y_pred_test_rf, pos_label='positive', average='micro')

#print("Random Forest - recall score - Training Accuracy:", recall)
print("Random Forest - recall score - Test Accuracy:", recall)
# Out:
# Random Forest - recall score - Test Accuracy: 0.7906976744186046
# C:\Users\anura\anaconda5-3-25\Lib\site-packages\sklearn\metrics\_classification.py:1583: UserWarning: Note that pos_label (set to 'positive') is ignored when average != 'binary' (got 'micro'). You may use labels=[pos_label] to specify a single positive class.
#   warnings.warn(

# %%
#f1score = f1_score(Y_train, y_pred_train_rf,pos_label='positive', average='micro')
f1score = f1_score(Y_test, y_pred_test_rf,pos_label='positive', average='micro')

#print("Random Forest -f1 score - Training Accuracy:", f1score)
print("Random Forest -f1 score - Test Accuracy:", f1score)
# Out:
# Random Forest -f1 score - Test Accuracy: 0.7906976744186046
# C:\Users\anura\anaconda5-3-25\Lib\site-packages\sklearn\metrics\_classification.py:1583: UserWarning: Note that pos_label (set to 'positive') is ignored when average != 'binary' (got 'micro'). You may use labels=[pos_label] to specify a single positive class.
#   warnings.warn(

# %% [markdown]
# ### Bagging and Boosting Methods

# %%
#apply the Bagging method

from sklearn.ensemble import RandomForestClassifier

# Random Forest Classifier
rf_model = RandomForestClassifier(n_estimators=100, random_state=42,
                                  max_samples=0.6, max_features=0.7,max_depth=10)
rf_model.fit(X_train, Y_train)

y_pred_train_rf = rf_model.predict(X_train)
y_pred_test_rf = rf_model.predict(X_test)

#training_accuracy_rf = accuracy_score(Y_train, y_pred_train_rf)
test_accuracy_rf = accuracy_score(Y_test, y_pred_test_rf)
precision =precision_score(Y_test, y_pred_test_rf,  pos_label='positive', average='micro')
recall  =recall_score(Y_test, y_pred_test_rf, pos_label='positive', average='micro')
f1score = f1_score(Y_test, y_pred_test_rf,pos_label='positive', average='micro')




#print("Random Forest - Training Accuracy:", training_accuracy_rf)
print("Random Forest - Test Accuracy:", test_accuracy_rf)
print("Random Forest -precision score - Test Accuracy:", precision)
print("Random Forest - recall score - Test Accuracy:", recall)
print("Random Forest -f1 score - Test Accuracy:", f1score)
# Out:
# Random Forest - Test Accuracy: 0.7906976744186046
# Random Forest -precision score - Test Accuracy: 0.7906976744186046
# Random Forest - recall score - Test Accuracy: 0.7906976744186046
# Random Forest -f1 score - Test Accuracy: 0.7906976744186046
# C:\Users\anura\anaconda5-3-25\Lib\site-packages\sklearn\metrics\_classification.py:1583: UserWarning: Note that pos_label (set to 'positive') is ignored when average != 'binary' (got 'micro'). You may use labels=[pos_label] to specify a single positive class.
#   warnings.warn(
# C:\Users\anura\anaconda5-3-25\Lib\site-packages\sklearn\metrics\_classification.py:1583: UserWarning: Note that pos_label (set to 'positive') is ignored when average != 'binary' (got 'micro'). You may use labels=[pos_label] to specify a single positive class.
#   warnings.warn(
# ...

# %%
#gradient boosting classifier 

from sklearn.ensemble import GradientBoostingClassifier
from sklearn.metrics import accuracy_score, log_loss

# Fit the model
gb_model = GradientBoostingClassifier(n_estimators=100, learning_rate=0.1, random_state=42)
gb_model.fit(X_train, Y_train)

# Predictions (labels)
y_pred_train_gb = gb_model.predict(X_train)
y_pred_test_gb = gb_model.predict(X_test)

# Predictions (probabilities) — for log loss
y_proba_train_gb = gb_model.predict_proba(X_train)
y_proba_test_gb = gb_model.predict_proba(X_test)

# Accuracy
training_accuracy_gb = accuracy_score(Y_train, y_pred_train_gb)
test_accuracy_gb = accuracy_score(Y_test, y_pred_test_gb)

# Log Loss (using probabilities)
training_loss_gb = log_loss(Y_train, y_proba_train_gb)
test_loss_gb = log_loss(Y_test, y_proba_test_gb)

# Output
print("Gradient Boosting - Training Accuracy:", training_accuracy_gb)
print("Gradient Boosting - Test Accuracy:", test_accuracy_gb)
print("Gradient Boosting - Training Loss:", training_loss_gb)
print("Gradient Boosting - Test Loss:", test_loss_gb)
# Out:
# Gradient Boosting - Training Accuracy: 1.0
# Gradient Boosting - Test Accuracy: 0.7209302325581395
# Gradient Boosting - Training Loss: 0.002888979526288007
# Gradient Boosting - Test Loss: 1.5730293963600444

# %%
##adaboost classifier with decision tree

from sklearn.ensemble import AdaBoostClassifier
from sklearn.metrics import accuracy_score, log_loss

# AdaBoost Classifier
ab_model = AdaBoostClassifier(n_estimators=100, random_state=42, learning_rate=0.1)
ab_model.fit(X_train, Y_train)

# Predicted class labels
y_pred_train_ab = ab_model.predict(X_train)
y_pred_test_ab = ab_model.predict(X_test)

# Predicted probabilities (for log loss)
y_proba_train_ab = ab_model.predict_proba(X_train)
y_proba_test_ab = ab_model.predict_proba(X_test)

# Accuracy scores
training_accuracy_ab = accuracy_score(Y_train, y_pred_train_ab)
test_accuracy_ab = accuracy_score(Y_test, y_pred_test_ab)

# Log loss (correct: using probabilities)
training_loss_ab = log_loss(Y_train, y_proba_train_ab)
test_loss_ab = log_loss(Y_test, y_proba_test_ab)

# Output
print("AdaBoost - Training Accuracy:", training_accuracy_ab)
print("AdaBoost - Test Accuracy:", test_accuracy_ab)
print("AdaBoost - Training Loss:", training_loss_ab)
print("AdaBoost - Test Loss:", test_loss_ab)
# Out:
# C:\Users\anura\anaconda5-3-25\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:527: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# AdaBoost - Training Accuracy: 0.5087719298245614
# AdaBoost - Test Accuracy: 0.46511627906976744
# AdaBoost - Training Loss: 0.8562774535796979
# AdaBoost - Test Loss: 1.2683995946852593

# %%
##XGBoost models

import xgboost as xgb
from sklearn.metrics import accuracy_score, log_loss
from sklearn.preprocessing import LabelEncoder

# Encode labels to start from 0 and be integers
le = LabelEncoder()
Y_train_enc = le.fit_transform(Y_train)
Y_test_enc = le.transform(Y_test)

# XGBoost Classifier
xgb_model = xgb.XGBClassifier(
    n_estimators=100,
    learning_rate=0.1,
    gamma=100,
    reg_lambda=10,
    use_label_encoder=False,
    eval_metric='logloss'
)
xgb_model.fit(X_train, Y_train_enc)

# Predictions (class labels)
y_pred_train_xgb = xgb_model.predict(X_train)
y_pred_test_xgb = xgb_model.predict(X_test)

# Predictions (probabilities for log_loss)
y_proba_train_xgb = xgb_model.predict_proba(X_train)
y_proba_test_xgb = xgb_model.predict_proba(X_test)

# Accuracy
training_accuracy_xgb = accuracy_score(Y_train_enc, y_pred_train_xgb)
test_accuracy_xgb = accuracy_score(Y_test_enc, y_pred_test_xgb)

# Log loss
training_loss_xgb = log_loss(Y_train_enc, y_proba_train_xgb)
test_loss_xgb = log_loss(Y_test_enc, y_proba_test_xgb)

# Output
print("XGBoost - Training Accuracy:", training_accuracy_xgb)
print("XGBoost - Test Accuracy:", test_accuracy_xgb)
print("XGBoost - Training Loss:", training_loss_xgb)
print("XGBoost - Test Loss:", test_loss_xgb)
# Out:
# XGBoost - Training Accuracy: 0.3567251461988304
# XGBoost - Test Accuracy: 0.3488372093023256
# XGBoost - Training Loss: 1.5049501620993468
# XGBoost - Test Loss: 1.5238411322764576
# C:\Users\anura\anaconda5-3-25\Lib\site-packages\xgboost\training.py:183: UserWarning: [22:58:24] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)

# %%
#Explain Bagging and Boosting methods. How is it different from each other.
print('''
Feature	                     Bagging	                  Boosting
Training	            Parallel (independent models)	  Sequential (each model corrects previous)
Goal	                Reduce variance	                  Reduce bias (and variance)
Sample Weighting	    Equal	                          Focus on previous errors (higher weights for mistakes)
Example             	Random Forest	                  AdaBoost, Gradient Boosting, XGBoost
Overfitting	            Less prone	                      Can overfit without tuning
Complexity	            Simpler to train	              More complex and slower
''')
# Out:
# Feature	                     Bagging	                  Boosting
# Training	            Parallel (independent models)	  Sequential (each model corrects previous)
# Goal	                Reduce variance	                  Reduce bias (and variance)
# Sample Weighting	    Equal	                          Focus on previous errors (higher weights for mistakes)
# Example             	Random Forest	                  AdaBoost, Gradient Boosting, XGBoost
# Overfitting	            Less prone	                      Can overfit without tuning
# Complexity	            Simpler to train	              More complex and slower

# %%
#Explain how to handle imbalance in the data.

print('''
* Handling imbalanced data is crucial in machine learning, especially for classification tasks.
Imbalanced data occurs when one class significantly outnumbers the others 
for example, 90% class A and 10% class B. This can lead to a model that performs well overall (accuracy-wise) 
but fails to correctly predict the minority class.

* Handling imbalance in data involves addressing situations where one class significantly outnumbers others. 
Common techniques include oversampling the minority class (e.g., using SMOTE) or undersampling the majority class to balance the dataset. 
Another approach is using class weights in algorithms to penalize misclassifications of minority classes. 
It's also important to use evaluation metrics like F1-score or ROC-AUC instead of accuracy. 
Ensemble methods like Balanced Random Forest can further improve performance on imbalanced datasets.
''')
# Out:
# * Handling imbalanced data is crucial in machine learning, especially for classification tasks.
# Imbalanced data occurs when one class significantly outnumbers the others
# for example, 90% class A and 10% class B. This can lead to a model that performs well overall (accuracy-wise)
# but fails to correctly predict the minority class.
#
# * Handling imbalance in data involves addressing situations where one class significantly outnumbers others.
# Common techniques include oversampling the minority class (e.g., using SMOTE) or undersampling the majority class to balance the dataset.
# Another approach is using class weights in algorithms to penalize misclassifications of minority classes.
# It's also important to use evaluation metrics like F1-score or ROC-AUC instead of accuracy.
# Ensemble methods like Balanced Random Forest can further improve performance on imbalanced datasets.
